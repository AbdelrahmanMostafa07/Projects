# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Display all columns in the dataframe

pd.set_option('display.max_columns',None)

# %%
# Read the dataset from a CSV file

data = pd.read_csv('train.csv')

# %%
# Display first 5 rows of the dataset

data.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  pc  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2   2         20       756  2549     9     7         19
# 1        136        3   6        905      1988  2631    17     3          7
# 2        145        5   6       1263      1716  2603    11     2          9
# 3        131        6   9       1216      1786  2769    16     8         11
# 4        141        2  14       1208      1212  1411     8     2         15
#
#    three_g  touch_screen  wifi  price_range
# ...

# %%
# Display the shape (rows, columns) of the dataset

data.shape
# Out:
# (2000, 21)

# %%
# Display information about the dataset (data types, non-null values, etc.)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
# Display the column names in the dataset

data.columns
# Out:
# Index(['battery_power', 'blue', 'clock_speed', 'dual_sim', 'fc', 'four_g',
#        'int_memory', 'm_dep', 'mobile_wt', 'n_cores', 'pc', 'px_height',
#        'px_width', 'ram', 'sc_h', 'sc_w', 'talk_time', 'three_g',
#        'touch_screen', 'wifi', 'price_range'],
#       dtype='object')

# %%
# Check for duplicated rows in the dataset

data.duplicated().any()
# Out:
# False

# %%
# Check for missing values in each column of the dataset

data.isnull().sum()
# Out:
# battery_power    0
# blue             0
# clock_speed      0
# dual_sim         0
# fc               0
# four_g           0
# int_memory       0
# m_dep            0
# mobile_wt        0
# n_cores          0
# pc               0
# px_height        0
# px_width         0
# ram              0
# sc_h             0
# sc_w             0
# talk_time        0
# three_g          0
# touch_screen     0
# wifi             0
# price_range      0
# dtype: int64

# %%
# Create a line plot to visualize the relationship between 'ram' and 'price_range'

sns.lineplot(data = data, x='price_range', y='ram', errorbar=None)
plt.title('The relationship between ram and phone price')
plt.xlabel('price')
# Out:
# Text(0.5, 0, 'price')

# %% [markdown]
# # Discover how many mobiles has bluetooth or not

# %%
data['blue'].value_counts()
# Out:
# 0    1010
# 1     990
# Name: blue, dtype: int64

# %%
# Create a count plot to visualize the distribution of 'blue' (Bluetooth)


plt.figure(figsize=(10,5))
ax = sns.countplot(data=data, x='blue')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '1010'), Text(0, 0, '990')]

# %%
# Display the correlation between features and the target variable 'price_range'

data.corr()['price_range']
# Out:
# battery_power    0.200723
# blue             0.020573
# clock_speed     -0.006606
# dual_sim         0.017444
# fc               0.021998
# four_g           0.014772
# int_memory       0.044435
# m_dep            0.000853
# mobile_wt       -0.030302
# n_cores          0.004399
# pc               0.033599
# px_height        0.148858
# px_width         0.165818
# ram              0.917046
# sc_h             0.022986
# sc_w             0.038711
# talk_time        0.021859
# three_g          0.023611
# touch_screen    -0.030411
# wifi             0.018785
# price_range      1.000000
# Name: price_range, dtype: float64

# %% [markdown]
# # Discover the front camera mega pixels

# %%
data['fc'].value_counts().head(10)
# Out:
# 0    474
# 1    245
# 2    189
# 3    170
# 5    139
# 4    133
# 6    112
# 7    100
# 9     78
# 8     77
# Name: fc, dtype: int64

# %%
sns.set_style('') #white , #darkgrid, #whitegrid, dark, ticks
sns.set_context('') #paper, #talk, #poster

# %%
# Create a bar plot to visualize the distribution of 'fc' (front camera mega pixels)


plt.figure(figsize=(10,5))
plt.xticks(rotation=0)
data['fc'].value_counts().head(10).plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
# Display the correlation matrix for all numerical features

data.corr()
# Out:
#                battery_power      blue  clock_speed  dual_sim        fc  \
# battery_power       1.000000  0.011252     0.011482 -0.041847  0.033334
# blue                0.011252  1.000000     0.021419  0.035198  0.003593
# clock_speed         0.011482  0.021419     1.000000 -0.001315 -0.000434
# dual_sim           -0.041847  0.035198    -0.001315  1.000000 -0.029123
# fc                  0.033334  0.003593    -0.000434 -0.029123  1.000000
# four_g              0.015665  0.013443    -0.043073  0.003187 -0.016560
# int_memory         -0.004004  0.041177     0.006545 -0.015679 -0.029133
# m_dep               0.034085  0.004049    -0.014364 -0.022142 -0.001791
# mobile_wt           0.001844 -0.008605     0.012350 -0.008979  0.023618
# n_cores            -0.029727  0.036161    -0.005724 -0.024658 -0.013356
# pc                  0.031441 -0.009952    -0.005245 -0.017143  0.644595
# px_height           0.014901 -0.006872    -0.014523 -0.020875 -0.009990
# ...

# %%
# Create a heatmap to visualize the correlation matrix


plt.figure(figsize=(15,7))
sns.heatmap(data.corr(), annot=True, fmt='.2f', linewidth=2)
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Number of cores of processor

# %%
data['n_cores'].value_counts()
# Out:
# 4    274
# 7    259
# 8    256
# 2    247
# 3    246
# 5    246
# 1    242
# 6    230
# Name: n_cores, dtype: int64

# %%
# Create a bar plot to visualize the relationship between 'n_cores' and 'price_range'


plt.figure(figsize=(10,5))
sns.barplot(data = data , x = 'n_cores', y = 'price_range')
plt.xlabel('Number of cores')
# Out:
# Text(0.5, 0, 'Number of cores')

# %% [markdown]
# # Mobile has 4G or not

# %%
data['four_g'].value_counts()
# Out:
# 1    1043
# 0     957
# Name: four_g, dtype: int64

# %%
# Create a count plot to visualize the distribution of 'four_g'


plt.figure(figsize=(10,5))
fourg = sns.countplot(data=data, x='four_g')
fourg.bar_label(fourg.containers[0])
# Out:
# [Text(0, 0, '957'), Text(0, 0, '1043')]

# %%
# Create a boxplot to visualize the distribution of 'battery_power'


plt.figure(figsize=(10,5))
sns.boxplot(data['battery_power'])
# Out:
# <AxesSubplot: >

# %%
# Display the distribution of 'price_range'

data['price_range'].value_counts()
# Out:
# 1    500
# 2    500
# 3    500
# 0    500
# Name: price_range, dtype: int64

# %%
# Create a bar plot to visualize the relationship between 'price_range', 'ram', and 'blue'


plt.figure(figsize=(10,5))
sns.barplot(data=data, x='price_range', y='ram', hue='blue')
# Out:
# <AxesSubplot: xlabel='price_range', ylabel='ram'>

# %%
# Create a bar plot to visualize the relationship between 'talk_time' and 'price_range'


plt.figure(figsize=(10,5))
sns.barplot(data=data, x='talk_time', y= 'price_range')
# Out:
# <AxesSubplot: xlabel='talk_time', ylabel='price_range'>

# %%
# Create KDE plots for each feature in the dataset


for feature in data:
    data=data.copy()
    sns.displot(data=data, x=feature, kind='kde')
    plt.xlabel(feature)
    plt.ylabel('count')
    plt.title(features)
    plt.show()

# %%
# Create subplots to visualize the relationship between categorical features and 'price_range'


fig, axes = plt.subplots(2,3, figsize=(18,10))
fig.suptitle('Price Range vs All Numerical Factors')
sns.countplot(ax = axes[0,0], data=data, x='three_g', palette='RdPu')
sns.countplot(ax = axes[0,1], data=data, x='touch_screen', palette='RdPu')
sns.countplot(ax = axes[0,2], data=data, x='four_g', palette='RdPu')
sns.countplot(ax = axes[1,0], data=data, x='wifi', palette='RdPu')
sns.countplot(ax = axes[1,1], data=data, x='fc', palette='RdPu')
sns.countplot(ax = axes[1,2], data=data, x='dual_sim', palette='RdPu')
plt.show()

# %%
# Separate features (X) and target variable (y)

X = data.drop('price_range',axis=1)
y = data['price_range']

# %%
# Display the first 5 rows of features (X)

X.head()
# Out:
#    battery_power  clock_speed  pc  px_height  px_width   ram  sc_h
# 0            842          2.2   2         20       756  2549     9
# 1           1021          0.5   6        905      1988  2631    17
# 2            563          0.5   6       1263      1716  2603    11
# 3            615          2.5   9       1216      1786  2769    16
# 4           1821          1.2  14       1208      1212  1411     8

# %%
# Display the first 5 rows of features (y)

y.head()
# Out:
# 0    1
# 1    2
# 2    2
# 3    2
# 4    1
# Name: price_range, dtype: int64

# %% [markdown]
# # Feature Selection

# %% [markdown]
# # Apply SelectKBest Algorithm

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
# Fit SelectKBest to the data

ordered_rank_features = SelectKBest(score_func=chi2, k=10)
ordered_feature = ordered_rank_features.fit(X,y)

# %%
ordered_feature
# Out:
# SelectKBest(score_func=<function chi2 at 0x00000208287AB600>)

# %%
# Display the selected features using SelectKBest

dfscores = pd.DataFrame(ordered_feature.scores_,columns=['Score'])
dfcolumns = pd.DataFrame(X.columns)

# %%
dfcolumns
# Out:
#                 0
# 0   battery_power
# 1            blue
# 2     clock_speed
# 3        dual_sim
# 4              fc
# 5          four_g
# 6      int_memory
# 7           m_dep
# 8       mobile_wt
# 9         n_cores
# 10             pc
# 11      px_height
# 12       px_width
# 13            ram
# 14           sc_h
# 15           sc_w
# 16      talk_time
# 17        three_g
# 18   touch_screen
# 19           wifi

# %%
features_rank = pd.concat([dfscores,dfcolumns],axis=1)

# %%
features_rank.columns = ['Feature', 'Score']
features_rank.sort_values(by='Score', ascending = True)
# Out:
#           Feature          Score
# 0    14129.866576  battery_power
# 1        0.723232           blue
# 2        0.648366    clock_speed
# 3        0.631011       dual_sim
# 4       10.135166             fc
# 5        1.521572         four_g
# 6       89.839124     int_memory
# 7        0.745820          m_dep
# 8       95.972863      mobile_wt
# 9        9.097556        n_cores
# 10       9.186054             pc
# 11   17363.569536      px_height
# 12    9810.586750       px_width
# 13  931267.519053            ram
# 14       9.614878           sc_h
# 15      16.480319           sc_w
# 16      13.236400      talk_time
# 17       0.327643        three_g
# 18       1.928429   touch_screen
# 19       0.422091           wifi

# %%
# Display the top 10 selected features using SelectKBest

features_rank.nlargest(10,'Feature')
# Out:
#           Feature          Score
# 13  931267.519053            ram
# 11   17363.569536      px_height
# 0    14129.866576  battery_power
# 12    9810.586750       px_width
# 8       95.972863      mobile_wt
# 6       89.839124     int_memory
# 15      16.480319           sc_w
# 16      13.236400      talk_time
# 4       10.135166             fc
# 14       9.614878           sc_h

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# ExtraTreesClassifier()

# %%
model.feature_importances_
# Out:
# array([0.06297587, 0.01960422, 0.03267964, 0.01964042, 0.03152408,
#        0.01687248, 0.03327217, 0.03250664, 0.03571314, 0.0332911 ,
#        0.03211795, 0.04683055, 0.04872386, 0.40127911, 0.03299254,
#        0.03294108, 0.03392626, 0.01435736, 0.01832306, 0.02042847])

# %%
# Display the feature importances


ranked_features = pd.Series(model.feature_importances_ , index = X.columns)
ranked_features.nlargest(10).plot(kind='barh')
plt.show()

# %% [markdown]
# # Information Gain

# %%
from sklearn.feature_selection import mutual_info_classif
mutual_info = mutual_info_classif(X,y)
mutual_data = pd.Series(mutual_info, index = X.columns)
mutual_data.sort_values(ascending=False)
# Out:
# ram              0.847055
# int_memory       0.033664
# px_width         0.032566
# battery_power    0.031275
# px_height        0.029434
# wifi             0.028025
# dual_sim         0.025737
# pc               0.018947
# talk_time        0.018894
# sc_w             0.017633
# touch_screen     0.013325
# fc               0.006286
# blue             0.002134
# sc_h             0.000107
# four_g           0.000000
# m_dep            0.000000
# mobile_wt        0.000000
# n_cores          0.000000
# clock_speed      0.000000
# three_g          0.000000
# dtype: float64

# %%
# Drop unnecessary columns based on feature selection

data = data.drop(['wifi', 'touch_screen', 'three_g', 'talk_time', 'sc_w', 'dual_sim', 'four_g', 'int_memory', 'blue', 'n_cores', 'mobile_wt', 'm_dep', 'fc'], axis=1)

# %%
data.head()
# Out:
#    battery_power  clock_speed  pc  px_height  px_width   ram  sc_h  \
# 0            842          2.2   2         20       756  2549     9
# 1           1021          0.5   6        905      1988  2631    17
# 2            563          0.5   6       1263      1716  2603    11
# 3            615          2.5   9       1216      1786  2769    16
# 4           1821          1.2  14       1208      1212  1411     8
#
#    price_range
# 0            1
# 1            2
# 2            2
# 3            2
# 4            1

# %%
print(X.shape)
print(y.shape)
# Out:
# (2000, 7)
# (2000,)

# %%
# Split the data into training and testing sets


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.25, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1500, 7)
# (500, 7)
# (1500,)
# (500,)

# %% [markdown]
# # Feature Sclaing

# %%
# Apply StandardScaler for feature scaling


from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
X_train
# Out:
# array([[-1.58954736, -0.54409463,  0.69550098, ...,  1.47195821,
#          0.79794809,  1.11590168],
#        [-1.06204271, -0.42202734, -1.28723859, ..., -1.73439382,
#          0.97495824,  1.35539982],
#        [ 1.31059626, -0.29996004,  0.86072928, ...,  0.65885313,
#          1.15196839,  1.35539982],
#        ...,
#        [-0.09759213,  0.55451104, -1.45246689, ...,  0.87998086,
#          1.4053724 ,  0.15790911],
#        [-0.09532817,  1.04278023, -0.4610971 , ...,  1.26465096,
#         -1.00010238,  0.39740725],
#        [-1.19335288, -1.27649842,  1.52164247, ..., -0.75083612,
#          0.29579825, -1.0395816 ]])

# %% [markdown]
# # Logistic Regression

# %%
# Apply Logistic Regression for classification


from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train,y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
print(y_pred)
# Out:
# [3 0 2 2 2 0 0 3 3 1 1 3 0 2 3 0 3 2 2 1 0 0 3 1 2 2 3 1 3 1 1 0 2 0 2 3 0
#  0 3 3 2 1 3 3 1 3 0 1 2 1 1 3 0 3 0 2 2 2 0 3 3 1 3 2 1 2 3 2 2 2 3 2 1 0
#  1 3 2 2 1 2 3 3 3 0 0 0 2 1 2 3 1 2 2 1 0 3 3 3 0 3 1 1 3 1 3 2 2 3 2 3 3
#  0 0 1 3 3 0 0 1 0 0 3 2 2 1 1 1 1 0 2 1 3 3 3 3 3 3 2 0 1 1 2 1 3 0 3 0 0
#  2 0 1 1 1 1 3 0 0 3 1 3 2 1 3 1 2 3 3 2 1 0 3 1 2 3 3 0 2 2 3 1 2 1 0 1 2
#  1 2 0 3 3 1 1 0 2 3 0 1 2 2 0 3 3 2 1 2 3 3 3 0 0 0 2 3 3 0 0 1 3 1 3 3 3
#  0 0 2 2 3 1 0 2 0 0 0 3 3 1 2 2 1 1 0 2 3 3 0 0 1 3 3 2 3 0 3 1 1 0 2 3 3
#  2 0 0 1 2 3 2 2 3 1 1 0 3 3 2 1 3 2 2 2 1 0 2 2 1 0 0 2 2 2 2 0 1 3 0 1 2
#  3 0 2 0 1 1 3 0 0 2 3 1 2 0 2 0 3 0 3 3 2 3 1 2 2 1 1 1 0 1 0 3 1 0 3 1 0
#  1 3 0 3 1 2 0 1 3 0 2 1 1 2 1 1 0 2 0 0 3 1 2 3 2 2 0 3 2 1 1 3 2 3 3 3 0
#  2 0 3 0 1 1 2 3 1 3 1 2 0 1 2 3 0 0 1 3 0 3 0 1 2 1 1 0 2 1 0 1 3 0 3 3 0
#  2 1 3 1 1 3 2 0 3 2 2 0 0 3 0 1 1 1 3 2 3 2 0 3 0 0 1 3 0 0 3 2 2 2 3 0 0
# ...

# %%
from sklearn.metrics import accuracy_score
acc1 = accuracy_score(y_test, y_pred)
print(f'Accuracy Score: {acc1}')
# Out:
# Accuracy Score: 0.956

# %% [markdown]
# # SVM Algorithm

# %%
from sklearn.svm import SVC
classifier = SVC(kernel = 'linear', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %% [markdown]
# # Predict the testset Score

# %%
y_pred = classifier.predict(X_train)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[121   3   0   0]
#  [  2 107   1   0]
#  [  0   5 116   4]
#  [  0   0   7 134]]

# %%
acc2 = accuracy_score(y_test, y_pred)

# %%
print(f'Accuracy Score: {acc2}')
# Out:
# Accuracy Score: 0.956

# %% [markdown]
# # Training the K-NN model on the Training set

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = classifier.predict(X_test)
print(y_pred)
# Out:
# [3 0 2 1 2 0 0 2 2 1 0 3 0 2 3 0 3 1 2 1 0 0 3 0 2 1 3 1 3 1 1 0 2 0 2 3 0
#  0 3 3 2 1 3 2 0 3 0 2 2 1 1 2 1 3 0 2 2 2 0 2 3 1 3 2 1 2 2 2 1 1 3 2 1 0
#  1 3 2 1 2 2 3 3 3 0 0 0 2 2 2 2 1 1 1 1 1 2 2 3 0 3 2 1 2 1 3 2 3 3 2 3 2
#  0 0 0 1 3 0 0 1 0 0 3 2 2 1 1 1 0 0 2 1 3 2 3 3 3 3 2 0 1 0 2 1 3 0 2 0 0
#  2 0 1 1 1 1 3 0 0 2 2 3 2 1 2 1 2 3 3 3 1 0 3 1 1 2 3 0 1 1 3 0 2 1 0 1 2
#  1 2 0 3 2 1 1 0 2 3 0 1 2 1 0 3 3 3 1 1 2 3 3 1 0 0 2 3 3 0 0 1 2 2 3 3 3
#  0 0 2 2 2 1 0 2 1 0 0 3 2 0 2 1 1 1 0 3 3 3 0 0 1 3 3 1 3 0 3 1 0 0 2 3 2
#  1 0 0 1 2 3 2 2 3 2 1 1 3 3 1 1 3 2 2 2 1 0 2 1 1 0 0 3 2 2 2 0 1 2 0 1 3
#  3 0 2 0 1 1 3 0 0 1 3 1 1 0 1 0 3 0 2 3 2 3 1 1 2 1 2 1 0 1 0 2 1 0 3 1 0
#  1 2 0 3 2 2 0 1 3 0 1 1 1 2 1 1 0 2 0 0 3 1 2 3 2 1 0 3 2 1 2 3 2 3 3 3 0
#  2 0 3 0 1 1 2 2 1 3 1 2 0 2 2 2 0 0 1 3 0 2 0 1 2 1 0 0 3 0 1 0 3 0 3 3 0
#  2 1 3 2 1 3 2 0 3 2 1 0 0 3 0 0 1 2 3 2 3 2 0 3 0 0 0 3 0 0 2 3 2 1 2 0 0
# ...

# %%
from sklearn.metrics import  accuracy_score
acc3 = accuracy_score(y_test, y_pred)

# %%
print(f"Accuracy score: {acc3}")
# Out:
# Accuracy score: 0.77

# %% [markdown]
# # Training the Naive Bayes on the Training set

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import  accuracy_score
acc4 = accuracy_score(y_test, y_pred)

# %%
print(f"Accuracy score : {acc4}")
# Out:
# Accuracy score : 0.828

# %% [markdown]
# # Training Decision Tree Classification on Train set

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %%
from sklearn.metrics import  accuracy_score
acc5 = accuracy_score(y_test, y_pred)

# %%
print(f"Accuracy score: {acc5}")
# Out:
# Accuracy score: 0.866

# %% [markdown]
# # Create visualization for all model with their Accuracy

# %%
# Append accuracy scores and model names to the lists


mylist=[]
mylist2=[]
mylist.append(acc1)
mylist2.append("Logistic Regression")
mylist.append(acc2)
mylist2.append("SVM")
mylist.append(acc3)
mylist2.append("KNN")
mylist.append(acc4)
mylist2.append("Naive Bayes")
mylist.append(acc5)
mylist2.append("DTR")

# %%
# Create a bar plot to visualize the accuracy of different classification models


plt.rcParams['figure.figsize']=10,5
sns.set_style("darkgrid")
ax = sns.barplot(x=mylist2, y=mylist, palette = "rocket", saturation =1.5)
plt.xlabel("Classification Models", fontsize = 20 )
plt.ylabel("Accuracy", fontsize = 20)
plt.title("Accuracy of different Classification Models", fontsize = 18)
plt.xticks(fontsize = 11, horizontalalignment = 'center', rotation = None)
plt.yticks(fontsize = 13)

# Annotate the bars with the corresponding accuracy values

for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy() 
    ax.annotate(f'{height:.2%}', (x + width/2, y + height*1.02), ha='center', fontsize = 'x-large')
plt.show()
